# %%
# importing libraries
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine
import psycopg2
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.preprocessing import StandardScaler
import numpy as np
from sklearn.metrics import mean_absolute_error,mean_squared_error, r2_score

# %%
# creating an engine to connect to postgres
# need to add .gitignore for password
engine = create_engine('postgresql+psycopg2://postgres:postgres@localhost/Avocados')

# %%
# reflecting Database into ORM classes
Base = automap_base()
Base.prepare(autoload_with=engine)
Base.classes.keys()
# Out:
# ['type', 'market', 'avocados', 'region']

# %%
# creating a session
session = Session(engine)

# %%
# creating our classes for each table in our 'Avocado' Database
avocados = Base.classes.avocados
market = Base.classes.market
type = Base.classes.type
region = Base.classes.region

# %%
# we used the 'read_sql' and 'join' function to merge all of our tables into one and created a pandas DataFrame
avocado_df = pd.read_sql(session.query(avocados, region, type, market)
                         .join(region, region.index == avocados.region_)
                         .join(market, market.index == avocados.market_)
                         .join(type, type.index == avocados.type_).statement, session.bind)
avocado_df.head(10)
# Out:
#    index        date  averageprice  totalvolume    plu4046    plu4225  \
# 0      0  2015-01-04          1.22     40873.28    2819.50   28287.42
# 1      1  2015-01-04          1.79      1373.95      57.42     153.88
# 2      2  2015-01-04          1.00    435021.49  364302.39   23821.16
# 3      3  2015-01-04          1.76      3846.69    1500.15     938.35
# 4      4  2015-01-04          1.08    788025.06   53987.31  552906.04
# 5      5  2015-01-04          1.29     19137.28    8040.64    6557.47
# 6      6  2015-01-04          1.01     80034.32   44562.12   24964.23
# 7      7  2015-01-04          1.64      1505.12       1.27    1129.50
# 8      8  2015-01-04          1.02    491738.00    7193.87  396752.18
# 9      9  2015-01-04          1.83      2192.13       8.66     939.43
#
#     plu4770  totalbags  smallbags  largebags  xlargebags  type_  region_  \
# 0     49.90    9716.46    9186.93     529.53         0.0      0        0
# ...

# %%
#
avocado_df = avocado_df.drop(columns=['type_', 'region_', 'market_', 'index_1', 'index_2', 'index_3'])
avocado_df.head(10)
# Out:
#    index        date  averageprice  totalvolume    plu4046    plu4225  \
# 0      0  2015-01-04          1.22     40873.28    2819.50   28287.42
# 1      1  2015-01-04          1.79      1373.95      57.42     153.88
# 2      2  2015-01-04          1.00    435021.49  364302.39   23821.16
# 3      3  2015-01-04          1.76      3846.69    1500.15     938.35
# 4      4  2015-01-04          1.08    788025.06   53987.31  552906.04
# 5      5  2015-01-04          1.29     19137.28    8040.64    6557.47
# 6      6  2015-01-04          1.01     80034.32   44562.12   24964.23
# 7      7  2015-01-04          1.64      1505.12       1.27    1129.50
# 8      8  2015-01-04          1.02    491738.00    7193.87  396752.18
# 9      9  2015-01-04          1.83      2192.13       8.66     939.43
#
#     plu4770  totalbags  smallbags  largebags  xlargebags               region  \
# 0     49.90    9716.46    9186.93     529.53         0.0               Albany
# ...

# %%
avocado_df['date'] = pd.to_datetime(avocado_df['date'])
avocado_df.dtypes
# Out:
# index                    int64
# date            datetime64[ns]
# averageprice           float64
# totalvolume            float64
# plu4046                float64
# plu4225                float64
# plu4770                float64
# totalbags              float64
# smallbags              float64
# largebags              float64
# xlargebags             float64
# region                  object
# type                    object
# market                  object
# dtype: object

# %%
avocado_df['month'] = pd.DatetimeIndex(avocado_df['date']).month
avocado_df
# Out:
#        index       date  averageprice  totalvolume    plu4046    plu4225  \
# 0          0 2015-01-04      1.220000     40873.28    2819.50   28287.42
# 1          1 2015-01-04      1.790000      1373.95      57.42     153.88
# 2          2 2015-01-04      1.000000    435021.49  364302.39   23821.16
# 3          3 2015-01-04      1.760000      3846.69    1500.15     938.35
# 4          4 2015-01-04      1.080000    788025.06   53987.31  552906.04
# ...      ...        ...           ...          ...        ...        ...
# 45022  53408 2023-12-03      1.616528      4947.25     154.75     194.69
# 45023  53409 2023-12-03      1.421139     24520.55     222.70      91.35
# 45024  53410 2023-12-03      1.550513      5693.91     204.64    1211.25
# 45025  53412 2023-12-03      1.618931     34834.86   15182.42    1211.38
# 45026  53413 2023-12-03      1.245406      2942.83    1058.54       7.46
#
#         plu4770  totalbags  smallbags  largebags  xlargebags  \
# ...

# %%
bins = [0, 3, 6, 9, 12]
labels = ['Q1', 'Q2', 'Q3', 'Q4']
avocado_df['quarter'] = pd.cut(avocado_df['month'], bins=bins, labels=labels)
avocado_df=avocado_df.drop(columns=['date', 'month'])
avocado_df['quarter'] = avocado_df['quarter'].astype(str)
avocado_df.dtypes
# Out:
# index             int64
# averageprice    float64
# totalvolume     float64
# plu4046         float64
# plu4225         float64
# plu4770         float64
# totalbags       float64
# smallbags       float64
# largebags       float64
# xlargebags      float64
# region           object
# type             object
# market           object
# quarter          object
# dtype: object

# %%
y = avocado_df['averageprice']
# this line to drop market (.58)
#X = avocado_df.drop(columns=['index', 'averageprice', 'totalvolume', 'smallbags', 'largebags', 'xlargebags', 'market'])
# this line to drop region (.52)
#X = avocado_df.drop(columns=['index', 'averageprice', 'totalvolume', 'smallbags', 'largebags', 'xlargebags', 'region'])
# this line to drop type (.38)
#X = avocado_df.drop(columns=['index', 'averageprice', 'totalvolume', 'smallbags', 'largebags', 'xlargebags', 'type'])
# this line to drop quarter (.56)
#X = avocado_df.drop(columns=['index', 'averageprice', 'totalvolume', 'smallbags', 'largebags', 'xlargebags', 'quarter'])
# this line to drop totalbags (.58)
#X = avocado_df.drop(columns=['index', 'averageprice', 'totalvolume', 'smallbags', 'largebags', 'xlargebags', 'totalbags'])
# this line to drop all bags (.58)
#X = avocado_df.drop(columns=['index', 'averageprice', 'totalvolume', 'totalbags', 'smallbags', 'largebags', 'xlargebags', 'totalbags', 'market'])
# this model to test 2 dimensional
X = avocado_df['totalvolume']

# %%
model = LinearRegression()

# %%
X = pd.get_dummies(X)
X
# Out:
#        84.56       379.82      385.55      419.98      472.82      478.98      \
# 0           False       False       False       False       False       False
# 1           False       False       False       False       False       False
# 2           False       False       False       False       False       False
# 3           False       False       False       False       False       False
# 4           False       False       False       False       False       False
# ...           ...         ...         ...         ...         ...         ...
# 45022       False       False       False       False       False       False
# 45023       False       False       False       False       False       False
# 45024       False       False       False       False       False       False
# 45025       False       False       False       False       False       False
# 45026       False       False       False       False       False       False
#
# ...

# %%
#
X= X.rename(str,axis="columns")

# %%
# Split the dataset using train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Instantiate a StandardScaler instance
scaler = StandardScaler()

# Fit the training data to the standard scaler
X_scaler = scaler.fit(X_train)

# Transform the training data using the scaler
X_train_scaled = X_scaler.transform(X_train)

# Transform the testing data using the scaler
X_test_scaled = X_scaler.transform(X_test)

# %%
model.fit(X_train_scaled, y_train)

# %%
y_pred = model.predict(X_test_scaled)

# %%
# run evaluation metrics to test perfofmance of the model
mae = mean_absolute_error(y_test, y_pred) 
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
  
print("The mean absolute value is:",mae) 
print("The mean square error is:",mse) 
print("The root mean square error is:",rmse)
print("The R squared is:", r2)

# %%
session.close()
